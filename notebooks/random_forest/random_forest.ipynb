# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression, LogisticRegression, Lasso
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, median_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from tqdm.notebook import tqdm
from PIL import Image
import joblib

# %%
df = pd.read_csv('../../corpus/calculated_metrics_full.csv', index_col=False)
df = df.rename(columns={"expert_evaluation": "review", "Sample 1": "review"})
df['true_mask_pixels'] = 0
df['pred_mask_pixels'] = 0

# %%
def calc_pixels(path):
    img = Image.open(f'../../{path}').convert('L')
    np_img = np.array(img)
    np_img[np_img > 0] = 1
    return np.count_nonzero(np_img)

# %%
for i in tqdm(df.index, ncols='100%'):
    true_mask_path = df.loc[i, ['path_truth_mask']][0][3:]
    pred_mask_path = df.loc[i, ['path_pred_mask']][0][3:]
    
    df.loc[i,['true_mask_pixels']] = calc_pixels(true_mask_path)
    df.loc[i,['pred_mask_pixels']] = calc_pixels(pred_mask_path)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, layout=Layout(flex='2'), max=146.0), HTML(value='')), …

# %%
df
# Out:
#                  case                           path_orig  \
# 0    00000150_002.png  ../dataset/Origin/00000150_002.png
# 1    00000181_061.png  ../dataset/Origin/00000181_061.png
# 2    00000211_019.png  ../dataset/Origin/00000211_019.png
# 3    00000211_041.png  ../dataset/Origin/00000211_041.png
# 4    00000344_003.png  ../dataset/Origin/00000344_003.png
# ..                ...                                 ...
# 141  00010815_006.png  ../dataset/Origin/00010815_006.png
# 142  00011157_001.png  ../dataset/Origin/00011157_001.png
# 143  00011237_006.png  ../dataset/Origin/00011237_006.png
# 144  00011355_011.png  ../dataset/Origin/00011355_011.png
# 145  00011450_000.png  ../dataset/Origin/00011450_000.png
#
#                               path_pred_mask  \
# 0    ../dataset/sample_1/00000150_002_s1.png
# 1    ../dataset/sample_1/00000181_061_s1.png
# 2    ../dataset/sample_1/00000211_019_s1.png
# 3    ../dataset/sample_1/00000211_041_s1.png
# 4    ../dataset/sample_1/00000344_003_s1.png
# ..                                       ...
# 141  ../dataset/sample_3/00010815_006_s3.png
# 142  ../dataset/sample_3/00011157_001_s3.png
# 143  ../dataset/sample_3/00011237_006_s3.png
# 144  ../dataset/sample_3/00011355_011_s3.png
# 145  ../dataset/sample_3/00011450_000_s3.png
#
#                                path_truth_mask  review      DICE     JACRD  \
# 0    ../dataset/Expert/00000150_002_expert.png       5  0.520065  0.351411
# 1    ../dataset/Expert/00000181_061_expert.png       4  0.519559  0.350949
# 2    ../dataset/Expert/00000211_019_expert.png       4  0.708670  0.548791
# 3    ../dataset/Expert/00000211_041_expert.png       3  0.562957  0.391747
# 4    ../dataset/Expert/00000344_003_expert.png       2  0.169319  0.092489
# ..                                         ...     ...       ...       ...
# 141  ../dataset/Expert/00010815_006_expert.png       5  0.856152  0.748485
# 142  ../dataset/Expert/00011157_001_expert.png       2  0.338908  0.204027
# 143  ../dataset/Expert/00011237_006_expert.png       5  0.519079  0.350511
# 144  ../dataset/Expert/00011355_011_expert.png       3  0.304123  0.179331
# 145  ../dataset/Expert/00011450_000_expert.png       3  0.315453  0.187263
#
#           AUC     KAPPA    RNDIND  ...    ACURCY   FALLOUT        TP  \
# 0    0.675705  0.519415  0.996630  ...  0.998312  0.000000     959.0
# 1    0.935726  0.473689  0.807597  ...  0.892172  0.113676   61136.0
# 2    0.936005  0.648735  0.806597  ...  0.891534  0.124482  138332.0
# 3    0.872117  0.476487  0.716678  ...  0.829149  0.184200  115382.0
# 4    0.776563  0.123700  0.654238  ...  0.777703  0.222226   23756.0
# ..        ...       ...       ...  ...       ...       ...       ...
# 141  0.874242  0.849609  0.974763  ...  0.987218  0.000000   39886.0
# 142  0.605593  0.323076  0.910738  ...  0.953176  0.002939   12585.0
# 143  0.837288  0.494596  0.904282  ...  0.949601  0.041161   28520.0
# 144  0.872778  0.257612  0.737018  ...  0.844252  0.158072   35687.0
# 145  0.593943  0.304776  0.925389  ...  0.961188  0.000226    9377.0
#
#            FP         TN       FN    REFVOL    SEGVOL  true_mask_pixels  \
# 0         0.0  1045847.0   1770.0    2729.0     959.0              2729
# 1    112143.0   874374.0    923.0   62059.0  173279.0             62059
# 2    113248.0   796509.0    487.0  138819.0  251580.0            138819
# 3    170256.0   754044.0   8894.0  124276.0  285638.0            124276
# 4    226212.0   791725.0   6883.0   30639.0  249968.0             30639
# ..        ...        ...      ...       ...       ...               ...
# 141       0.0   995287.0  13403.0   53289.0   39886.0             53289
# 142    2909.0   986893.0  46189.0   58774.0   15494.0             58774
# 143   41520.0   967209.0  11327.0   39847.0   70040.0             39847
# 144  159508.0   849575.0   3806.0   39493.0  195195.0             39493
# 145     226.0   998502.0  40471.0   49848.0    9603.0             49848
#
#      pred_mask_pixels
# 0                 959
# 1              173279
# 2              251580
# 3              285638
# 4              249968
# ..                ...
# 141             39886
# 142             15494
# 143             70040
# 144            195195
# 145              9603
#
# [146 rows x 35 columns]

# %%
model = RandomForestRegressor(n_estimators=100, max_features ='sqrt')

# %%
features = ['true_mask_pixels', 'pred_mask_pixels', 'HDRFDST', 'AVGDIST']
target = 'review'

# %%
X = df[features]
y = df[target]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

model.fit(X_train, y_train)
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

print('Mean AE train: {:.3f}, test: {:.3f}'.format(
    mean_absolute_error(y_train, y_train_pred),
    mean_absolute_error(y_test, y_test_pred)))
# Out:
# Mean AE train: 0.235, test: 0.529

# %%
joblib.dump(model, '../../models/random_forest/rf_2m-0.529.cbm')
# Out:
# ['../../models/random_forest/rf_2m-0.529.cbm']
